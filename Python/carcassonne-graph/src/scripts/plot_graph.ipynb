# %%
from pathlib import Path

import matplotlib.pyplot as plt

from Carcassonne.graph.draw import draw_board
from Carcassonne.state.board import Board

f = Path('/Users/am0472/PycharmProjects/carcassonne-graph/data/raw/self_play_data/20220407_105009_c3a7d257-1313-40e9-a708-b8229c34a2d5_71.graphml')
board = Board.from_graphml(f)
fig = plt.gcf()
fig.set_size_inches(22,17)
draw_board(board)

# %%
while len(board.nodes) > 237:
    board.previous

# %%
turn = board.nodes[list(board.nodes)[-1]]['turn']
turn
# Out:
# 56

# %%
list(filter(lambda n: board.nodes[n]['turn'] == turn, board.nodes ))
# Out:
# [229, 230, 231, 232, 233]
